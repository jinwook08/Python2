# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('cold2017.xlsx')

# %%
data
# Out:
#      Unnamed: 0        월.일  강정동  건입동   구좌  남원읍  대정읍  색달동  서귀동  서호동   성산  아라동  \
# 0             0 2017-01-01    3  6.0  5.6  4.6  3.5  4.3  0.5  0.5  0.5  0.5
# 1             1 2017-01-02  7.8  9.8  7.6  9.2  9.3  8.5  5.0  5.0  5.0  5.0
# 2             2 2017-01-03  5.9  6.9  5.1  5.2  6.8  4.6  1.0  1.0  1.0  1.0
# 3             3 2017-01-04    3  6.0  5.5  3.2  6.0  4.2 -0.1 -0.1 -0.1 -0.1
# 4             4 2017-01-05  7.5  8.4  7.6  7.9  8.7  8.1  2.2  2.2  2.2  2.2
# ..          ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 360         360 2017-12-27  1.2  2.4  0.7  2.5  2.1  1.9 -3.3 -3.3 -3.3 -3.3
# 361         361 2017-12-28  1.6  2.3  3.1  3.1  2.8  1.3 -3.1 -3.1 -3.1 -3.1
# 362         362 2017-12-29  2.4  4.0  4.0  6.1  3.9  2.6 -0.9 -0.9 -0.9 -0.9
# 363         363 2017-12-30  4.6  9.5  7.8  7.2  7.3  6.8  4.6  4.6  4.6  4.6
# 364         364 2017-12-31  3.6  6.7  6.1  5.7  6.2  4.0  2.3  2.3  2.3  2.3
#
#      오등동 외도일동   용담    우도   월정  표선읍  한림읍
# ...

# %%
data2 = pd.read_excel('cold2018.xlsx')

# %%
data2.drop(data2.columns[[0,0]], axis = 'columns')
data.drop(data.columns[[0,0]], axis = 'columns')
# Out:
#            월.일  강정동  건입동   구좌  남원읍  대정읍  색달동  서귀동  서호동   성산  아라동  오등동 외도일동  \
# 0   2017-01-01    3  6.0  5.6  4.6  3.5  4.3  0.5  0.5  0.5  0.5  2.0    3
# 1   2017-01-02  7.8  9.8  7.6  9.2  9.3  8.5  5.0  5.0  5.0  5.0  6.1  7.8
# 2   2017-01-03  5.9  6.9  5.1  5.2  6.8  4.6  1.0  1.0  1.0  1.0  1.6  5.9
# 3   2017-01-04    3  6.0  5.5  3.2  6.0  4.2 -0.1 -0.1 -0.1 -0.1  0.6    3
# 4   2017-01-05  7.5  8.4  7.6  7.9  8.7  8.1  2.2  2.2  2.2  2.2  3.8  7.5
# ..         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 360 2017-12-27  1.2  2.4  0.7  2.5  2.1  1.9 -3.3 -3.3 -3.3 -3.3 -2.2  1.2
# 361 2017-12-28  1.6  2.3  3.1  3.1  2.8  1.3 -3.1 -3.1 -3.1 -3.1 -2.2  1.6
# 362 2017-12-29  2.4  4.0  4.0  6.1  3.9  2.6 -0.9 -0.9 -0.9 -0.9  0.0  2.4
# 363 2017-12-30  4.6  9.5  7.8  7.2  7.3  6.8  4.6  4.6  4.6  4.6  6.4  4.6
# 364 2017-12-31  3.6  6.7  6.1  5.7  6.2  4.0  2.3  2.3  2.3  2.3  3.9  3.6
#
#       용담    우도   월정  표선읍  한림읍
# 0    5.0   8.8  6.7  3.7  4.3
# ...

# %%
data3 = pd.read_excel('cold2019.xlsx')

# %%
df = pd.concat([data, data2,data3])

# %%
df
# Out:
#      Unnamed: 0        월.일  강정동  건입동   구좌  남원읍  대정읍  색달동  서귀동  서호동   성산  아라동  \
# 0             0 2017-01-01    3  6.0  5.6  4.6  3.5  4.3  0.5  0.5  0.5  0.5
# 1             1 2017-01-02  7.8  9.8  7.6  9.2  9.3  8.5  5.0  5.0  5.0  5.0
# 2             2 2017-01-03  5.9  6.9  5.1  5.2  6.8  4.6  1.0  1.0  1.0  1.0
# 3             3 2017-01-04    3  6.0  5.5  3.2    6  4.2 -0.1 -0.1 -0.1 -0.1
# 4             4 2017-01-05  7.5  8.4  7.6  7.9  8.7  8.1  2.2  2.2  2.2  2.2
# ..          ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 360         360 2019-12-27  5.7  5.7  5.4  5.3  4.7  4.7  1.4  1.4  1.4  1.4
# 361         361 2019-12-28  6.1  6.1    2  3.8  3.5  3.8  1.1  1.1  1.1  1.1
# 362         362 2019-12-29  7.1  7.1  3.6  6.5  8.2  7.1  4.8  4.8  4.8  4.8
# 363         363 2019-12-30  6.3  6.3  6.1  7.4  5.7  5.5  2.4  2.4  2.4  2.4
# 364         364 2019-12-31  1.8  1.8  0.8  1.6  1.3  0.7 -2.2 -2.2 -2.2 -2.2
#
#      오등동 외도일동   용담    우도   월정  표선읍  한림읍
# ...

# %%
df.drop(df.columns[[0,0]], axis = 'columns')
# Out:
#            월.일  강정동  건입동   구좌  남원읍  대정읍  색달동  서귀동  서호동   성산  아라동  오등동 외도일동  \
# 0   2017-01-01    3  6.0  5.6  4.6  3.5  4.3  0.5  0.5  0.5  0.5  2.0    3
# 1   2017-01-02  7.8  9.8  7.6  9.2  9.3  8.5  5.0  5.0  5.0  5.0  6.1  7.8
# 2   2017-01-03  5.9  6.9  5.1  5.2  6.8  4.6  1.0  1.0  1.0  1.0  1.6  5.9
# 3   2017-01-04    3  6.0  5.5  3.2    6  4.2 -0.1 -0.1 -0.1 -0.1  0.6    3
# 4   2017-01-05  7.5  8.4  7.6  7.9  8.7  8.1  2.2  2.2  2.2  2.2  3.8  7.5
# ..         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 360 2019-12-27  5.7  5.7  5.4  5.3  4.7  4.7  1.4  1.4  1.4  1.4  3.1  5.7
# 361 2019-12-28  6.1  6.1    2  3.8  3.5  3.8  1.1  1.1  1.1  1.1  1.2  6.1
# 362 2019-12-29  7.1  7.1  3.6  6.5  8.2  7.1  4.8  4.8  4.8  4.8  3.8  7.1
# 363 2019-12-30  6.3  6.3  6.1  7.4  5.7  5.5  2.4  2.4  2.4  2.4  3.8  6.3
# 364 2019-12-31  1.8  1.8  0.8  1.6  1.3  0.7 -2.2 -2.2 -2.2 -2.2 -0.8  1.8
#
#       용담    우도   월정  표선읍  한림읍
# 0    5.0   8.8  6.7  3.7  4.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1064 entries, 0 to 364
# Data columns (total 19 columns):
# Unnamed: 0    1064 non-null int64
# 월.일           1064 non-null datetime64[ns]
# 강정동           1063 non-null object
# 건입동           1064 non-null float64
# 구좌            1064 non-null object
# 남원읍           1064 non-null object
# 대정읍           1064 non-null object
# 색달동           1064 non-null object
# 서귀동           1064 non-null float64
# 서호동           1064 non-null float64
# 성산            1064 non-null float64
# 아라동           1064 non-null float64
# 오등동           1064 non-null float64
# 외도일동          1063 non-null object
# 용담            1064 non-null float64
# 우도            1064 non-null float64
# 월정            1064 non-null float64
# 표선읍           1064 non-null float64
# 한림읍           1064 non-null float64
# dtypes: datetime64[ns](1), float64(11), int64(1), object(6)
# memory usage: 166.2+ KB

# %%
df.drop(df.columns[[0,0]], axis = 'columns')
# Out:
#            월.일  강정동  건입동   구좌  남원읍  대정읍  색달동  서귀동  서호동   성산  아라동  오등동 외도일동  \
# 0   2017-01-01    3  6.0  5.6  4.6  3.5  4.3  0.5  0.5  0.5  0.5  2.0    3
# 1   2017-01-02  7.8  9.8  7.6  9.2  9.3  8.5  5.0  5.0  5.0  5.0  6.1  7.8
# 2   2017-01-03  5.9  6.9  5.1  5.2  6.8  4.6  1.0  1.0  1.0  1.0  1.6  5.9
# 3   2017-01-04    3  6.0  5.5  3.2    6  4.2 -0.1 -0.1 -0.1 -0.1  0.6    3
# 4   2017-01-05  7.5  8.4  7.6  7.9  8.7  8.1  2.2  2.2  2.2  2.2  3.8  7.5
# ..         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 360 2019-12-27  5.7  5.7  5.4  5.3  4.7  4.7  1.4  1.4  1.4  1.4  3.1  5.7
# 361 2019-12-28  6.1  6.1    2  3.8  3.5  3.8  1.1  1.1  1.1  1.1  1.2  6.1
# 362 2019-12-29  7.1  7.1  3.6  6.5  8.2  7.1  4.8  4.8  4.8  4.8  3.8  7.1
# 363 2019-12-30  6.3  6.3  6.1  7.4  5.7  5.5  2.4  2.4  2.4  2.4  3.8  6.3
# 364 2019-12-31  1.8  1.8  0.8  1.6  1.3  0.7 -2.2 -2.2 -2.2 -2.2 -0.8  1.8
#
#       용담    우도   월정  표선읍  한림읍
# 0    5.0   8.8  6.7  3.7  4.3
# ...

# %%
# Out:
#             Unnamed: 0       건입동       서귀동       서호동        성산       아라동  \
# Unnamed: 0    1.000000  0.406456  0.369919  0.369919  0.369919  0.369919
# 건입동           0.406456  1.000000  0.975170  0.975170  0.975170  0.975170
# 서귀동           0.369919  0.975170  1.000000  1.000000  1.000000  1.000000
# 서호동           0.369919  0.975170  1.000000  1.000000  1.000000  1.000000
# 성산            0.369919  0.975170  1.000000  1.000000  1.000000  1.000000
# 아라동           0.369919  0.975170  1.000000  1.000000  1.000000  1.000000
# 오등동           0.385257  0.988057  0.976241  0.976241  0.976241  0.976241
# 용담            0.421043  0.995016  0.971899  0.971899  0.971899  0.971899
# 우도            0.443371  0.984994  0.959280  0.959280  0.959280  0.959280
# 월정            0.403545  0.981133  0.963072  0.963072  0.963072  0.963072
# 표선읍           0.378658  0.976560  0.964335  0.964335  0.964335  0.964335
# 한림읍           0.400700  0.985142  0.966432  0.966432  0.966432  0.966432
#
# ...

# %%
data = pd.read_excel('201901_totData.xlsx')

data.corr()
# Out:
#             풍량        온도      거주인구      근무인구      방문인구      사업체수       학교수  \
# 풍량    1.000000 -0.393490  0.009041  0.021312 -0.022903 -0.040412  0.232068
# 온도   -0.393490  1.000000 -0.354201 -0.372680 -0.389826 -0.331853 -0.029500
# 거주인구  0.009041 -0.354201  1.000000  0.942892  0.889456  0.916482  0.272183
# 근무인구  0.021312 -0.372680  0.942892  1.000000  0.953183  0.916270  0.161945
# 방문인구 -0.022903 -0.389826  0.889456  0.953183  1.000000  0.929271  0.156941
# 사업체수 -0.040412 -0.331853  0.916482  0.916270  0.929271  1.000000  0.206471
# 학교수   0.232068 -0.029500  0.272183  0.161945  0.156941  0.206471  1.000000
# 숙박업수 -0.111379 -0.202139  0.067487  0.148658  0.340524  0.332478 -0.244207
#
#           숙박업수
# 풍량   -0.111379
# 온도   -0.202139
# 거주인구  0.067487
# 근무인구  0.148658
# 방문인구  0.340524
# 사업체수  0.332478
# 학교수  -0.244207
# 숙박업수  1.000000

# %%
data
# Out:
#        지역          풍량        온도          거주인구         근무인구          방문인구  \
# 0     강정동  164.770968  6.620968  16478.881720  1363.948029  11541.946237
# 1     건입동  164.770968  6.620968   8390.105735   965.338710   8262.304659
# 2     구좌읍  315.300000  5.846774  15058.741935  1387.514337   9087.433692
# 3     남원읍  166.583871  7.295161  16093.229391  1301.822581  10297.611111
# 4     대정읍  298.922581  6.280645  20306.134409  1272.523297   8230.641577
# 5     중문동  264.622581  7.090323  10028.548387   804.942652   6791.492832
# 6     서귀동  282.780645  2.351613   8333.344086  1605.586022  17445.172043
# 7     성산읍  282.780645  2.351613  15430.059140  1289.415771  11745.229391
# 8     아라동  282.780645  2.351613  43905.899642  4997.458781  16015.532258
# 9    외도일동  164.770968  6.620968  12135.012545   724.593190   6375.182796
# 10     용담  185.483871  5.850000  12572.976703  3044.231183  15914.069892
# 11    우도면  293.087097  7.061290   1467.543011    80.166667   1501.734767
# ...

# %%
data2 = pd.read_excel('201901_totData.xlsx')

# %%
data2
data.corr()
# Out:
#             풍량        온도      거주인구      근무인구      방문인구      사업체수       학교수  \
# 풍량    1.000000 -0.393490  0.009041  0.021312 -0.022903 -0.040412  0.232068
# 온도   -0.393490  1.000000 -0.354201 -0.372680 -0.389826 -0.331853 -0.029500
# 거주인구  0.009041 -0.354201  1.000000  0.942892  0.889456  0.916482  0.272183
# 근무인구  0.021312 -0.372680  0.942892  1.000000  0.953183  0.916270  0.161945
# 방문인구 -0.022903 -0.389826  0.889456  0.953183  1.000000  0.929271  0.156941
# 사업체수 -0.040412 -0.331853  0.916482  0.916270  0.929271  1.000000  0.206471
# 학교수   0.232068 -0.029500  0.272183  0.161945  0.156941  0.206471  1.000000
# 숙박업수 -0.111379 -0.202139  0.067487  0.148658  0.340524  0.332478 -0.244207
#
#           숙박업수
# 풍량   -0.111379
# 온도   -0.202139
# 거주인구  0.067487
# 근무인구  0.148658
# 방문인구  0.340524
# 사업체수  0.332478
# 학교수  -0.244207
# 숙박업수  1.000000

# %%
import seaborn as sns
from matplotlib import font_manager, rc
import matplotlib
import numpy as np

# %%
plt.figure(figsize=(15,15))
font_path = 'C:/Windows/Fonts/H2GTRM.TTF'   # 윈도 모든 폰트가 있는 곳
font_name = font_manager.FontProperties(fname=font_path).get_name()   # 폰트 이름을 가져온다 . 
# rc = resource configuration  폰트이름
matplotlib.rc('font', family = font_name)    # 가져 font를 출력 한다.
sns.heatmap(data = data.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# C:\Users\ICT01_12\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning:
#
# Glyph 8722 missing from current font.
#
# C:\Users\ICT01_12\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning:
#
# Glyph 8722 missing from current font.

# %%
data = data.corr()

sns.clustermap(data, 
              annot = True, 
              cmap = 'RdYlBu_r',
              vmin = -1, vmax = 1, )

# %%
data = data.corr()
# 그림 사이즈 지정
fig, ax = plt.subplots( figsize=(7,7) )

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(df, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵을 그린다
sns.heatmap(df, 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-94f18ef52b50> in <module>
#      14             linewidths=.5,  # 경계면 실선으로 구분하기
#      15             cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
# ---> 16             vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
#      17            )
#      18 plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ...
